# %%
from mahler import Mahler, solve_congruence

# %%
a = Mahler({1:1, 2:2})
b = Mahler({3:1, 0:2})

# %%
solve_congruence(a, b, 6)
# Out:
# [3]

# %%
(a*Mahler({3:1}))%6
# Out:
# 2[0] + [3]

# %%
b%6
# Out:
# 2[0] + [3]
